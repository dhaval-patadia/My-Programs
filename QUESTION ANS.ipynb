# %%
#-----Question ans-----

print('welcome everyone to the game: \nPress Hello to enter the game\n')
x=input('')
x=x.lower()
if (x=='hello'):
    print('\n\nYour 1st question is \n\nWhat is the national animal of India\nA=TIGER\nB=LION\nC=Peacock\nD=Deer')
    ans1=input('Choose the option: ')
    if (ans1=='A'):
        print('\nCONGRATULATIONS\n')
        print('\nWhat is National bird of India\nA=PEACOCK\nB=EAGLE\nC=FLEMINGO\nD=PARROT\n')
        ans2=input('Choose Your option: ')
        if(ans2=='A'):
            print('\nCONGRATULATIONS\n')
            print('\nHow many States and union territories are Their in India\nA=28 & 7\nB=29 & 8\nC=25 & 7\nD=20 & 5')
            ans3=input('Choose your option: ')
            if(ans3=='B'):
                print('\nCONGRATULATIONS\n')
                print('Who is the current Prime minister of India\nA=LAL BAHADUR SHASTRI\nB=PANDIT JAWAHARLAL NEHRU\nC=NARENDRA MODI\nD=ABDUL KALAM AZAD')
                ans4=input('Choose your option: ')
                if (ans4=='C'):
                    print('\nCONGRATULATIONS\n')
                    print('\nWho is Popular World Leader in 2020\nA=NARENDRA MODI\nB=DONALD TRUMP\nC=VLADIMIR PUTIN\nD=KIM JONG UN')
                    ans5=input('Choose your option: ')
                    if(ans5=='A'):
                        print('\nCONGRATULATIONS\n YOU WON THE GAME\n')                    
                    else:
                        print('\nSorry The Ans is Wrong \nBetter luck next time')
                else:
                    print('\nSorry The Ans is Wrong \nBetter luck next time')
            else:
                print('\nSorry The Ans is Wrong \nBetter luck next time')
        else:
            print('\nSorry The Ans is Wrong \nBetter luck next time')        
            
    else:
        print('\nSorry The Ans is Wrong \nBetter luck next time')
else:
    print('EXIT')
# Out:
# welcome everyone to the game:
# Press Hello to enter the game
#
# HELLO
#
#
# Your 1st question is
#
# What is the national animal of India
# A=TIGER
# B=LION
# C=Peacock
# D=Deer
# Choose the option: A
#
# CONGRATULATIONS
#
#
# What is National bird of India
# A=PEACOCK
# B=EAGLE
# C=FLEMINGO
# D=PARROT
#
# Choose Your option: A
#
# CONGRATULATIONS
#
#
# How many States and union territories are Their in India
# A=28 & 7
# B=29 & 8
# C=25 & 7
# D=20 & 5
# Choose your option: B
#
# CONGRATULATIONS
#
# Who is the current Prime minister of India
# A=LAL BAHADUR SHASTRI
# B=PANDIT JAWAHARLAL NEHRU
# C=NARENDRA MODI
# D=ABDUL KALAM AZAD
# Choose your option: C
#
# CONGRATULATIONS
#
#
# Who is Popular World Leader in 2020
# A=NARENDRA MODI
# B=DONALD TRUMP
# C=VLADIMIR PUTIN
# D=KIM JONG UN
# Choose your option: A
#
# CONGRATULATIONS
#  YOU WON THE GAME
